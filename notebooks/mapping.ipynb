# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20, 10)

# %%
import gshhg

# %%
shorelines = gshhg.GSHHG("../src/gshhg/tests/GSHHS_shp", resolution="crude")

# %%
shorelines.points(), shorelines.polygons()
# Out:
# (13071, 1787)

# %%
ds = shorelines.grid_mapping_mask(step=0.25)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 721, lon: 1440)
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.8 -179.5 -179.2 ... 179.2 179.5 179.8
#   * lat      (lat) float64 -90.0 -89.75 -89.5 -89.25 ... 89.25 89.5 89.75 90.0
# Data variables:
#     crs      int32 0
#     mask     (lat, lon) int8 dask.array<chunksize=(90, 90), meta=np.ndarray>

# %%
ds.mask.plot()

# %%
ds = shorelines.grid_mapping_distance_to_nearest(step=0.25)
ds
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 721, lon: 1440)
# Coordinates:
#   * lon       (lon) float64 -180.0 -179.8 -179.5 -179.2 ... 179.2 179.5 179.8
#   * lat       (lat) float64 -90.0 -89.75 -89.5 -89.25 ... 89.25 89.5 89.75 90.0
# Data variables:
#     crs       int32 0
#     distance  (lat, lon) float64 dask.array<chunksize=(721, 1440), meta=np.ndarray>

# %%
ds.distance.plot()
